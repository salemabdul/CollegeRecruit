# %%
import pandas as pd
placement = pd.read_csv("Downloads/Placement_Data_Full_Class.csv") #Dataset being read

# %%
placement #Dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
len(placement) #prints outs the number of rows in the dataset
# Out:
# 215

# %%
placement.shape #Prints out the rows and columns of the dataset
# Out:
# (215, 15)

# %%
placement.head() #Prints out the first couple of rows
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
placement.tail() #Prints out the last couple of rows
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %%
pd.set_option("display.max.rows", None) #Will show all of the rows in the dataset

# %%
placement #Full dataset with all of the rows shown
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
placement.head(3) #Shows the first three rows
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80  Placed  250000.0

# %%
placement.tail(3) #Shows the last three rows
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %%
placement.info() #Shows the column names of the dataset and their info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
placement.describe() #Statistics for the columns that are numberic
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
import numpy as np
placement.describe(include=np.object) #More descriptive statistics with categorical variables
# Out:
#        gender    ssc_b   hsc_b     hsc_s   degree_t workex specialisation  \
# count     215      215     215       215        215    215            215
# unique      2        2       2         3          3      2              2
# top         M  Central  Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# freq      139      116     131       113        145    141            120
#
#         status
# count      215
# unique       2
# top     Placed
# freq       148

# %%
placement["gender"].value_counts() #Counting up the number of times the values for each gender show up
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
placement["status"].value_counts() #Counting up the number of times of placed and not placed status
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
placement["workex"].value_counts() #Counting up the number of people who have work expereince and who does not have work experience
# Out:
# No     141
# Yes     74
# Name: workex, dtype: int64

# %%
placement["salary"].value_counts() #Counting up the number of times each salary shows up
# Out:
# 300000.0    22
# 250000.0    18
# 240000.0    15
# 260000.0     7
# 265000.0     6
# 200000.0     6
# 360000.0     6
# 220000.0     5
# 275000.0     5
# 270000.0     4
# 210000.0     4
# 400000.0     4
# 350000.0     3
# 216000.0     3
# 500000.0     3
# 280000.0     2
# 236000.0     2
# 218000.0     2
# 252000.0     2
# 204000.0     2
# 230000.0     2
# 276000.0     2
# 231000.0     1
# 380000.0     1
# 411000.0     1
# 650000.0     1
# 393000.0     1
# 225000.0     1
# 336000.0     1
# 264000.0     1
# 278000.0     1
# 287000.0     1
# 940000.0     1
# 340000.0     1
# 285000.0     1
# 425000.0     1
# 290000.0     1
# 690000.0     1
# 233000.0     1
# 255000.0     1
# 295000.0     1
# 450000.0     1
# 268000.0     1
# 420000.0     1
# 320000.0     1
# Name: salary, dtype: int64

# %%
placement["degree_t"].value_counts() #Counting up the number of each of the degrees that showed up in the datasert
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
placement["specialisation"].value_counts() #Counting up the number of each specialization
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
placement.loc[placement["gender"] == "M", "status"].value_counts() #Counting up the number of males who were placed and the number of males who were not placed
# Out:
# Placed        100
# Not Placed     39
# Name: status, dtype: int64

# %%
placement.loc[placement["gender"] == "F", "status"].value_counts() #Counting up the number of females who were placed and the number of females who were not placed
# Out:
# Placed        48
# Not Placed    28
# Name: status, dtype: int64

# %%
placement.loc[placement["gender"] == "M", "workex"].value_counts() #Counting up the number of males who have work experience and the number of males who do not have work experience
# Out:
# No     87
# Yes    52
# Name: workex, dtype: int64

# %%
placement.loc[placement["gender"] == "F", "workex"].value_counts() #Counting up the number of females who have work experience and the number of females who do not have work experience
# Out:
# No     54
# Yes    22
# Name: workex, dtype: int64

# %%
placement.loc[placement["degree_t"] == "Comm&Mgmt", "status"].value_counts() #Number of people who got a degree in comm&mgmt who were placed and the number of those who were not placed
# Out:
# Placed        102
# Not Placed     43
# Name: status, dtype: int64

# %%
placement.loc[placement["degree_t"] == "Sci&Tech", "status"].value_counts() #Number of people who got a degree in Sci&tech who were placed and the number of those who were not placed
# Out:
# Placed        41
# Not Placed    18
# Name: status, dtype: int64

# %%
placement.loc[placement["degree_t"] == "Sci&Tech", "workex"].value_counts() #Number of people who have a degree with work experience and the number of people who work and do not have work experience
# Out:
# No     34
# Yes    25
# Name: workex, dtype: int64

# %%
placement.loc[placement["degree_t"] == "Comm&Mgmt", "workex"].value_counts() #Number of people who have a degree with work experience and the number of people who work and do not have work experience
# Out:
# No     100
# Yes     45
# Name: workex, dtype: int64

# %%
placement.loc[placement["degree_t"] == "Others", "workex"].value_counts() #Number of people who have a degree with work experience and the number of people who work and do not have work experience
# Out:
# No     7
# Yes    4
# Name: workex, dtype: int64

# %%
placement.loc[placement["gender"] == "M", "workex"].value_counts() #Number of males who have work experience and number of males who do not have work experience
# Out:
# No     87
# Yes    52
# Name: workex, dtype: int64

# %%
placement.loc[placement["gender"] == "F", "workex"].value_counts() #Number of males who have work experience and number of females who do not have work experience
# Out:
# No     54
# Yes    22
# Name: workex, dtype: int64

# %%
placement["salary"].agg(("min", "max")) #minimum and maximum salary
# Out:
# min    200000.0
# max    940000.0
# Name: salary, dtype: float64

# %%
placement["etest_p"].agg(("min", "max")) #minimum and maximum score of the employability test
# Out:
# min    50.0
# max    98.0
# Name: etest_p, dtype: float64

# %%
placement.loc[placement["gender"] == "M", "etest_p"].agg(("min", "max")) #minimum and maximum score of the employability test for a male
# Out:
# min    50.0
# max    97.4
# Name: etest_p, dtype: float64

# %%
placement.loc[placement["gender"] == "F", "etest_p"].agg(("min", "max")) #minimum and maximum score of the employability test for a female
# Out:
# min    50.0
# max    98.0
# Name: etest_p, dtype: float64

# %%
placement.loc[placement["gender"] == "M", "salary"].agg(("min", "max")) #minimum and maximum salary for a male
# Out:
# min    200000.0
# max    940000.0
# Name: salary, dtype: float64

# %%
placement.loc[placement["gender"] == "F", "salary"].agg(("min", "max")) #minimum and maximum salary for a female
# Out:
# min    200000.0
# max    650000.0
# Name: salary, dtype: float64

# %%
placement.loc[placement["specialisation"] == "Mkt&HR", "status"].value_counts() #Counting up the number of people who speicalized in mkt&hr who were placed and not placed
# Out:
# Placed        53
# Not Placed    42
# Name: status, dtype: int64

# %%
placement.loc[placement["specialisation"] == "Mkt&Fin", "status"].value_counts() #Counting up the number of people who speicalized in mkt&Fin who were placed and not placed
# Out:
# Placed        95
# Not Placed    25
# Name: status, dtype: int64

# %%
placement.iloc[-2] #Second to last row of the dataset
# Out:
# sl_no                   214
# gender                    F
# ssc_p                    74
# ssc_b                Others
# hsc_p                    66
# hsc_b                Others
# hsc_s              Commerce
# degree_p                 58
# degree_t          Comm&Mgmt
# workex                   No
# etest_p                  70
# specialisation       Mkt&HR
# mba_p                 60.23
# status               Placed
# salary               204000
# Name: 213, dtype: object

# %%
placement.iloc[-5] #Fifth to last row the dataset
# Out:
# sl_no                   211
# gender                    M
# ssc_p                  80.6
# ssc_b                Others
# hsc_p                    82
# hsc_b                Others
# hsc_s              Commerce
# degree_p               77.6
# degree_t          Comm&Mgmt
# workex                   No
# etest_p                  91
# specialisation      Mkt&Fin
# mba_p                 74.49
# status               Placed
# salary               400000
# Name: 210, dtype: object

# %%
placement2 = placement.dropna() #Variable for dropping the null values

# %%
placement2.shape #Shows the number of rows and columns of the dataset
# Out:
# (148, 15)

# %%
len(placement2) #Shows the number of rows of the dataset
# Out:
# 148

# %%
placement3 = placement.rename( columns={"hsc_s": "secondary education sepcialization", "degree_p": "degree percentage", "degree_t": "degree type", "workex":"work experience", "etest_p": "employability test score"}) #renaming some of the columns

# %%
placement3.info() #info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sl_no                               215 non-null    int64
#  1   gender                              215 non-null    object
#  2   ssc_p                               215 non-null    float64
#  3   ssc_b                               215 non-null    object
#  4   hsc_p                               215 non-null    float64
#  5   hsc_b                               215 non-null    object
#  6   secondary education sepcialization  215 non-null    object
#  7   degree percentage                   215 non-null    float64
#  8   degree type                         215 non-null    object
#  9   work experience                     215 non-null    object
#  10  employability test score            215 non-null    float64
# ...

# %%
placement3["status"] = pd.Categorical(placement3["status"]) #Changes status to a categorical variable
placement3["status"].dtype
# Out:
# CategoricalDtype(categories=['Not Placed', 'Placed'], ordered=False)

# %%
placement3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sl_no                               215 non-null    int64
#  1   gender                              215 non-null    object
#  2   ssc_p                               215 non-null    float64
#  3   ssc_b                               215 non-null    object
#  4   hsc_p                               215 non-null    float64
#  5   hsc_b                               215 non-null    object
#  6   secondary education sepcialization  215 non-null    object
#  7   degree percentage                   215 non-null    float64
#  8   degree type                         215 non-null    object
#  9   work experience                     215 non-null    object
#  10  employability test score            215 non-null    float64
# ...

# %%
placement3["secondary education sepcialization"] = pd.Categorical(placement3["secondary education sepcialization"]) #changes secondary education specialization to a categorical variable
placement3["secondary education sepcialization"].dtype
# Out:
# CategoricalDtype(categories=['Arts', 'Commerce', 'Science'], ordered=False)

# %%
placement3["gender"] = pd.Categorical(placement3["gender"]) #changes gender to a categorical variable
placement3["gender"].dtype
# Out:
# CategoricalDtype(categories=['F', 'M'], ordered=False)

# %%
placement3["work experience"] = pd.Categorical(placement3["work experience"]) #changes work experience to a categorical variable
placement3["work experience"].dtype
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
placement3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sl_no                               215 non-null    int64
#  1   gender                              215 non-null    category
#  2   ssc_p                               215 non-null    float64
#  3   ssc_b                               215 non-null    object
#  4   hsc_p                               215 non-null    float64
#  5   hsc_b                               215 non-null    object
#  6   secondary education sepcialization  215 non-null    category
#  7   degree percentage                   215 non-null    float64
#  8   degree type                         215 non-null    object
#  9   work experience                     215 non-null    category
#  10  employability test score            215 non-null    float64
# ...

# %%
placement3["degree type"] = pd.Categorical(placement3["degree type"]) #changes degree type to a categorical variable
placement3["degree type"].dtype
# Out:
# CategoricalDtype(categories=['Comm&Mgmt', 'Others', 'Sci&Tech'], ordered=False)

# %%
placement3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sl_no                               215 non-null    int64
#  1   gender                              215 non-null    category
#  2   ssc_p                               215 non-null    float64
#  3   ssc_b                               215 non-null    object
#  4   hsc_p                               215 non-null    float64
#  5   hsc_b                               215 non-null    object
#  6   secondary education sepcialization  215 non-null    category
#  7   degree percentage                   215 non-null    float64
#  8   degree type                         215 non-null    category
#  9   work experience                     215 non-null    category
#  10  employability test score            215 non-null    float64
# ...

# %%
placement3["specialisation"] = pd.Categorical(placement3["specialisation"]) #changes specialisation to a categorical variable
placement3["specialisation"].dtype
# Out:
# CategoricalDtype(categories=['Mkt&Fin', 'Mkt&HR'], ordered=False)

# %%
placement3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sl_no                               215 non-null    int64
#  1   gender                              215 non-null    category
#  2   ssc_p                               215 non-null    float64
#  3   ssc_b                               215 non-null    object
#  4   hsc_p                               215 non-null    float64
#  5   hsc_b                               215 non-null    object
#  6   secondary education sepcialization  215 non-null    category
#  7   degree percentage                   215 non-null    float64
#  8   degree type                         215 non-null    category
#  9   work experience                     215 non-null    category
#  10  employability test score            215 non-null    float64
# ...

# %%
placement3.columns #Column names in an array
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b',
#        'secondary education sepcialization', 'degree percentage',
#        'degree type', 'work experience', 'employability test score',
#        'specialisation', 'mba_p', 'status', 'salary'],
#       dtype='object')

# %%
placement4 = placement3[['gender', 'degree percentage', 'degree type', 'work experience', 'employability test score', 'specialisation', 'status', 'salary']] #Selected column names
placement4
# Out:
#     gender  degree percentage degree type work experience  \
# 0        M              58.00    Sci&Tech              No
# 1        M              77.48    Sci&Tech             Yes
# 2        M              64.00   Comm&Mgmt              No
# 3        M              52.00    Sci&Tech              No
# 4        M              73.30   Comm&Mgmt              No
# 5        M              67.25    Sci&Tech             Yes
# 6        F              79.00   Comm&Mgmt              No
# 7        M              66.00    Sci&Tech             Yes
# 8        M              72.00   Comm&Mgmt              No
# 9        M              61.00   Comm&Mgmt              No
# 10       M              60.00   Comm&Mgmt             Yes
# 11       M              78.30   Comm&Mgmt             Yes
# 12       F              65.00   Comm&Mgmt              No
# 13       F              59.00   Comm&Mgmt              No
# 14       M              50.00   Comm&Mgmt              No
# ...

# %%
placement4.loc[placement4["work experience"] == "Yes", "status"].value_counts() #Counting up the people who have experience and placed and the number of people who do have work experience and not placed
# Out:
# Placed        64
# Not Placed    10
# Name: status, dtype: int64

# %%
placement4.loc[placement4["work experience"] == "No", "status"].value_counts() #Counting up the people who do not have experience and placed and the number of people who do not have work experience and not placed
# Out:
# Placed        84
# Not Placed    57
# Name: status, dtype: int64

# %%
placement4.loc[placement4["degree type"] == "Sci&Tech", "salary"].agg(("min", "max")) #Minimum and maximum salary of someone who has a degree type of science and technology
# Out:
# min    200000.0
# max    690000.0
# Name: salary, dtype: float64

# %%
placement4.loc[placement4["degree type"] == "Comm&Mgmt", "salary"].agg(("min", "max")) #Minimum and maximum salary of someone who has a degree type of communication and management
# Out:
# min    200000.0
# max    940000.0
# Name: salary, dtype: float64

# %%
placement4.loc[placement4["work experience"] == "Yes", "salary"].agg(("min", "max")) #minimum and maximum salary of someone who has work experience
# Out:
# min    200000.0
# max    940000.0
# Name: salary, dtype: float64

# %%
placement4.loc[placement4["work experience"] == "No", "salary"].agg(("min", "max")) #minimum and maximum salary of someone who does not have work experience
# Out:
# min    200000.0
# max    500000.0
# Name: salary, dtype: float64

# %%
# %matplotlib inline
placement4[(placement4["gender"] == "M") & (placement4["degree type"] == "Sci&Tech")]["status"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of males who had a degree type of science and technology who got placed and not placed with percentage included

# %%
# %matplotlib inline
placement4[(placement4["gender"] == "F") & (placement4["degree type"] == "Sci&Tech")]["status"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of females who had a degree type of science and technology who got placed and not placed with percentage included

# %%
placement4[(placement4["gender"] == "M") & (placement4["degree type"] == "Comm&Mgmt")]["status"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of males who had a degree type of communication and management who got placed and not placed with percentage included

# %%
placement4[(placement4["gender"] == "F") & (placement4["degree type"] == "Comm&Mgmt")]["status"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of females who had a degree type of communication and management who got placed and not placed with percentage included

# %%
placement4[(placement4["gender"] == "M") & (placement4["degree type"] == "Sci&Tech")]["work experience"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of males who had a degree type of science and technology and who has work experience and who doesn't with percentage included

# %%
placement4[(placement4["gender"] == "F") & (placement4["degree type"] == "Sci&Tech")]["work experience"].value_counts().plot(kind= "pie", autopct = '%1.1f%%') #pie chart of females who had a degree type of science and technology and who has work experience and who doesn't with percentage included

# %%
placement4[(placement4["work experience"] == "Yes")]["gender"].value_counts().plot(kind = "pie", autopct = '%1.1f%%') #Percentage of males and females who have work experience

# %%
placement4[(placement4["work experience"] == "No")]["gender"].value_counts().plot(kind = "pie", autopct = '%1.1f%%') #Percentage of males and females who do not have work experience

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(placement4["salary"])
x = plt.xlabel('salary for people')
y = plt.ylabel('frequency')
plt.title('frequency vs salary for people')
plt.show() #Shows histogram for the salaries that are the most frequent

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(placement4['employability test score'])
y = plt.ylabel('frequency')
plt.title('frequency vs employability test score')
plt.show() #Shows histogram for the employability test scores that are that are the most frequent

# %%
sns.boxplot(x= "gender", y= "salary", data= placement4) #Box and whiskers plot for the salaries for males and females showing the min, max, median, lower quartile, and upper quartile

# %%
sns.boxplot(x= "gender", y= "employability test score", data= placement4) #Box and whiskers plot for the employability test score for males and females showing the min, max, median, lower quartile, and upper quartile

# %%
sns.boxplot(placement4['salary']) #box and whisker plot of the salary in the dataset
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.boxplot(placement4['employability test score']) #box and whisker plot of the employability test score in the dataset
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.boxplot(x = "work experience", y = "salary", data=placement4 ) #box and whisker plot for the work experience and salary

# %%
sns.boxplot(x = "work experience", y = "employability test score", data=placement4 ) #box and whisker plot for the employability test score and work experience

# %%
 placement4["gender"].value_counts().plot(kind="bar") #Bar graph of each of the genders

# %%
placement4["status"].value_counts().plot(kind="bar") #Bar graph of each of the statuses

# %%
placement5 = placement4[(placement4["gender"] == "M")] #Filtering where we only have rows with the male gender
placement5
# Out:
#     gender  degree percentage degree type work experience  \
# 0        M              58.00    Sci&Tech              No
# 1        M              77.48    Sci&Tech             Yes
# 2        M              64.00   Comm&Mgmt              No
# 3        M              52.00    Sci&Tech              No
# 4        M              73.30   Comm&Mgmt              No
# 5        M              67.25    Sci&Tech             Yes
# 7        M              66.00    Sci&Tech             Yes
# 8        M              72.00   Comm&Mgmt              No
# 9        M              61.00   Comm&Mgmt              No
# 10       M              60.00   Comm&Mgmt             Yes
# 11       M              78.30   Comm&Mgmt             Yes
# 14       M              50.00   Comm&Mgmt              No
# 16       M              65.60   Comm&Mgmt             Yes
# 19       M              70.00   Comm&Mgmt             Yes
# 20       M              66.00   Comm&Mgmt              No
# ...

# %%
len(placement5) #number of rows
# Out:
# 139

# %%
placement5.shape #Number of rows and columns
# Out:
# (139, 8)

# %%
placement5.info() #Shows info of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 214
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    139 non-null    category
#  1   degree percentage         139 non-null    float64
#  2   degree type               139 non-null    category
#  3   work experience           139 non-null    category
#  4   employability test score  139 non-null    float64
#  5   specialisation            139 non-null    category
#  6   status                    139 non-null    category
#  7   salary                    100 non-null    float64
# dtypes: category(5), float64(3)
# memory usage: 5.5 KB

# %%
placement5.describe() #describing the numerical columns statistics
# Out:
#        degree percentage  employability test score         salary
# count         139.000000                139.000000     100.000000
# mean           65.429856                 72.926115  298910.000000
# std             6.748840                 13.213727   99514.792058
# min            50.000000                 50.000000  200000.000000
# 25%            60.450000                 61.140000  250000.000000
# 50%            65.000000                 72.000000  270000.000000
# 75%            70.100000                 84.135000  300000.000000
# max            83.000000                 97.400000  940000.000000

# %%
placement5["status"].value_counts().plot(kind="bar") #Bar graph of the males who were placed and not placed

# %%
placement5["degree type"].value_counts().plot(kind="bar") #Bar graph of the males degree type

# %%
placement5["work experience"].value_counts().plot(kind="bar") #Bar graph of the males work experience

# %%
sns.distplot(placement5["salary"])
x = plt.xlabel('salary')
y = plt.ylabel('frequency')
plt.title('frequency vs salary of males')
plt.show() #Showing histogram of the salaries that are frequent

# %%
sns.distplot(placement5["salary"])
x = plt.xlabel('salary')
y = plt.ylabel('frequency')
plt.title('frequency vs salary of males')
plt.xlim(200000, 500000)
plt.show() #Showing histogram of the salaries that are frequent in the range of 200000 and 500000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(placement5['employability test score'])
y = plt.ylabel('frequency')
plt.title('frequency vs employability test score')
plt.show() #Shows histogram for the employability test scores that are that are the most frequent for males

# %%
placement5[(placement5["degree type"] == "Sci&Tech") & (placement5["work experience"]=="Yes")]["status"].value_counts().plot(kind="pie", autopct = '%1.1f%%') #Showing a bar graph for the males who have a degree type of sci&tech and have work experience who were placed and not placed

# %%
placement5[(placement5["degree type"] == "Sci&Tech") & (placement5["work experience"]=="No")]["status"].value_counts().plot(kind="pie", autopct = '%1.1f%%') #Showing a bar graph for the males who have a degree type of sci&tech and have no work experience who were placed and not placed

# %%
placement5[(placement5["degree type"] == "Comm&Mgmt") & (placement5["work experience"]=="Yes")]["status"].value_counts().plot(kind="pie", autopct = '%1.1f%%') #Showing a bar graph for the males who have a degree type of communication and management and have work experience who were placed and not placed

# %%
placement5[(placement5["degree type"] == "Comm&Mgmt") & (placement5["work experience"]=="No")]["status"].value_counts().plot(kind="pie", autopct = '%1.1f%%') #Showing a bar graph for the males who have a degree type of communication and management and have work no experience who were placed and not placed

# %%
placement5[placement5["gender"] == "M"]["work experience"].value_counts().plot(kind="pie", autopct='%1.1f%%') #Shows a bar graph of the percentaages of males who have work experience and who does not have work experience

# %%
placement5[placement5["gender"] == "M"]["degree type"].value_counts().plot(kind="pie", autopct='%1.1f%%') #Shows a bar graph of the percentaages of males who have a degree type

# %%
sns.boxplot(placement5['salary']) #box and whisker plot of the salary column in the dataset
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
placement5.describe()
# Out:
#        degree percentage  employability test score         salary
# count         139.000000                139.000000     100.000000
# mean           65.429856                 72.926115  298910.000000
# std             6.748840                 13.213727   99514.792058
# min            50.000000                 50.000000  200000.000000
# 25%            60.450000                 61.140000  250000.000000
# 50%            65.000000                 72.000000  270000.000000
# 75%            70.100000                 84.135000  300000.000000
# max            83.000000                 97.400000  940000.000000

# %%
sns.boxplot(placement5['employability test score']) #box and whisker plot of the employability test score in the dataset
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
placement6 = placement5.loc[0:14,] #Selecting some rows from the dataset that includes only males

# %%
pd.set_option("display.precision", 2)

# %%
placement6
# Out:
#    gender  degree percentage degree type work experience  \
# 0       M              58.00    Sci&Tech              No
# 1       M              77.48    Sci&Tech             Yes
# 2       M              64.00   Comm&Mgmt              No
# 3       M              52.00    Sci&Tech              No
# 4       M              73.30   Comm&Mgmt              No
# 5       M              67.25    Sci&Tech             Yes
# 7       M              66.00    Sci&Tech             Yes
# 8       M              72.00   Comm&Mgmt              No
# 9       M              61.00   Comm&Mgmt              No
# 10      M              60.00   Comm&Mgmt             Yes
# 11      M              78.30   Comm&Mgmt             Yes
# 14      M              50.00   Comm&Mgmt              No
#
#     employability test score specialisation      status    salary
# 0                      55.00         Mkt&HR      Placed  270000.0
# 1                      86.50        Mkt&Fin      Placed  200000.0
# ...

# %%
placement6["degree type"].value_counts().plot(kind="bar") #Bar graph showing the number for each degree type for the males

# %%
sns.boxplot(x = "work experience", y = "employability test score", data=placement5 ) #box and whisker plot for the employability test score and work experience for males

# %%
sns.boxplot(x = "work experience", y = "salary", data=placement5) #box and whisker plot for the work experience and salary for males

# %%
placement5["degree type"].value_counts().plot(kind="bar") #Bar graph showing the number for each degree type for the males

# %%
placement
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
test = placement["etest_p"]
salary = placement["salary"]

# %%
plt.scatter(test, salary, edgecolors = 'r')
plt.xlabel('employability test score')
plt.ylabel('salary')
plt.show('salary vs test score')
plt.show() #Scatter plot showing the relationship between salary and test scores

# %%
placement
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
placement2.shape
# Out:
# (148, 15)

# %%
sns.boxplot(x = "workex", y = "salary", data=placement2) #box and whisker plot for the work experience and salary for males and females

# %%
placement2.describe()
# Out:
#         sl_no   ssc_p   hsc_p  degree_p  etest_p   mba_p     salary
# count  148.00  148.00  148.00    148.00   148.00  148.00     148.00
# mean   106.88   71.72   69.93     68.74    73.24   62.58  288655.41
# std     60.68    8.72    9.33      6.52    13.73    5.88   93457.45
# min      1.00   49.00   50.83     56.00    50.00   52.38  200000.00
# 25%     57.75   65.00   63.00     65.00    60.00   57.77  240000.00
# 50%    108.50   72.50   68.00     68.00    72.00   62.25  265000.00
# 75%    153.25   78.12   75.25     72.42    85.00   66.76  300000.00
# max    214.00   89.40   97.70     91.00    98.00   77.89  940000.00

# %%
placement2[placement2["gender"] == "M"]["degree_t"].value_counts().plot(kind="pie", autopct='%1.1f%%') #Shows a bar graph of the percentaages of males who have a degree type
